# %%
# !pip install cohere

# %%
# !pip install openai langchain tiktoken -q

# %% [markdown]
# ## Если используете ключ от OpenAI, запустите эту ячейку 👇

# %%
from langchain.chat_models import ChatOpenAI
import os
from getpass import getpass


# os.environ['OPENAI_API_KEY'] = "Введите ваш OpenAI API ключ"
os.environ['OPENAI_API_KEY'] = getpass(prompt='Введите ваш OpenAI API ключ')

# Инициализируем языковую модель
llm = ChatOpenAI(temperature=0.0)

# %% [markdown]
# ## Если используете ключ из курса, запустите эти ячейки 👇

# %%
# !wget https://raw.githubusercontent.com/a-milenkin/LLM_practical_course/main/notebooks/utils.py
# Out:
# --2023-12-05 17:57:48--  https://raw.githubusercontent.com/a-milenkin/LLM_practical_course/main/notebooks/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11052 (11K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]  10.79K  --.-KB/s    in 0s
#
# 2023-12-05 17:57:48 (95.8 MB/s) - ‘utils.py’ saved [11052/11052]

# %%
from utils import ChatOpenAI
from getpass import getpass

#course_api_key= "Введите ваш OpenAI API ключ"
course_api_key = getpass(prompt='Введите API ключ')

# Инициализируем языковую модель
llm = ChatOpenAI(temperature=0.0, course_api_key=course_api_key)
# Out:
# Введите API ключ··········

# %% [markdown]
# ## Задание 2.1.8 `LLM` — сила 💪, `ML` — могила 🧟

# %%
import pandas as pd

# %%
df = pd.read_csv('https://stepik.org/media/attachments/lesson/1084297/submission100lines.csv')

# %%
df.head()
# Out:
#    amount    text_id                                               text
# 0       2   14205200  Сниму жилье. 500-600 рублей сутки. Эконом клас...
# 1       6  319097075  ищем жилье в центре недалеко от моря с 23.07-0...
# 2       4   98881311  Ищем жилье на период с 18-28июля..на две семьи...
# 3       4   44587027  2 семьи по 3 человека (2 взрослых и ребенок) с...
# 4       3  352802829  Сниму недорогое жилье в лазаревском на 6 чел 3...

# %%
# Напишите шаблон промпт, указав инструкцию, вопрос и выходной индикатор

prompt_template = """Ответь на вопрос, опираясь на контекст ниже.
Если на вопрос нельзя ответить, используя информацию из контекста,
ответь '0'

Context: {text_input}

Question: Определи по данному контексту, сколько людей указано в тексте, отвечай строго в числовом формате без дополнительных слов.

Answer: ...
"""

# %%
amount_list = [] # Список, где будем хранить ответы модели

for text_input in df['text']:
    prompt = prompt_template.format(text_input=text_input) # Добавляем сообщение в промпт
    amount = llm.predict(prompt) # Ответ модели
    amount_list.append(amount) # Добавляем ответ в список
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-28-5251f69fd998> in <cell line: 3>()
#       3 for text_input in df['text']:
#       4     prompt = prompt_template.format(text_input=text_input) # Добавляем сообщение в промпт
# ----> 5     amount = llm.predict(prompt) # Ответ модели
#       6     amount_list.append(amount) # Добавляем ответ в список
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in predict(self, text, stop, **kwargs)
#     656         else:
#     657             _stop = list(stop)
# --> 658         result = self([HumanMessage(content=text)], stop=_stop, **kwargs)
#     659         if isinstance(result.content, str):
#     660             return result.content
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in __call__(self, messages, stop, callbacks, **kwargs)
#     620         **kwargs: Any,
#     621     ) -> BaseMessage:
# --> 622         generation = self.generate(
#     623             [messages], stop=stop, callbacks=callbacks, **kwargs
#     624         ).generations[0][0]
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     368                 if run_managers:
#     369                     run_managers[i].on_llm_error(e)
# --> 370                 raise e
#     371         flattened_outputs = [
#     372             LLMResult(generations=[res.generations], llm_output=res.llm_output)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, **kwargs)
#     358             try:
#     359                 results.append(
# --> 360                     self._generate_with_cache(
#     361                         m,
#     362                         stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     512                 )
#     513             if new_arg_supported:
# --> 514                 return self._generate(
#     515                     messages, stop=stop, run_manager=run_manager, **kwargs
#     516                 )
#
# /content/utils.py in _generate(self, messages, stop, run_manager, **kwargs)
#     166             **kwargs: Any,
#     167     ) -> ChatResult:
# --> 168         response = self.client.create([self._convert_message_to_dict(m) for m in messages], course_api_key=self.course_api_key)
#     169         return self._create_chat_result(response)
#     170
#
# /content/utils.py in create(cls, messages, model, course_api_key, **kwargs)
#      89                                       headers={"Authorization": f"Bearer {cls._auth}"})
#      90
# ---> 91         response.raise_for_status()
#      92         json_response = response.json()
#      93
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1019
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#    1023     def close(self):
#
# HTTPError: 504 Server Error: Gateway Time-out for url: https://api.neuraldeep.tech/chatgpt

# %%
df['amount'] = amount_list # Создаём новый столбец из ответов модели

# %%
df['amount']
# Out:
# 0     1
# 1     6
# 2     7
# 3     6
# 4     6
#      ..
# 95    9
# 96    1
# 97    2
# 98    2
# 99    3
# Name: amount, Length: 100, dtype: object

# %%
import numpy as np

# %%
df['amount'] = df['amount'].apply(lambda x: x if str(x).isdigit() else 0).astype('int32')

# %%
df
# Out:
#     amount    text_id                                               text
# 0        1   14205200  Сниму жилье. 500-600 рублей сутки. Эконом клас...
# 1        6  319097075  ищем жилье в центре недалеко от моря с 23.07-0...
# 2        7   98881311  Ищем жилье на период с 18-28июля..на две семьи...
# 3        6   44587027  2 семьи по 3 человека (2 взрослых и ребенок) с...
# 4        6  352802829  Сниму недорогое жилье в лазаревском на 6 чел 3...
# ..     ...        ...                                                ...
# 95       9  233661411  Добрый день! Ищем жилье на 9 человек, 4 взросл...
# 96       1   77792435  Здравствуйте. Ищем жильё в период с 26 мая по ...
# 97       2  102311098  Добрый день! Ищем жилье в Лазаревском с 02.07-...
# 98       2  123993850  Ищем не дорогое жильё на начало июля , не дале...
# 99       3   54495881  ищем жилье с 8-20 августа с бассейном 3мест но...
#
# [100 rows x 3 columns]

# %%
df.to_csv('2_1_8_solution.csv', index=False) # Сохраняем файл, отправляем на Stepik, получаем баллы :)
